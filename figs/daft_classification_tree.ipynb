# %%
# %pylab inline
from matplotlib import rc
rc("font", family="serif", size=12)
rc("text", usetex=True)

import daft
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.5/dist-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['rc']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
pgm = daft.PGM([15.3, 10.05], origin=[0.3, 0.3])

# %%
pgm.add_node(daft.Node("1", r"$\\ v_{\infty, cl}<=157.0173\\ Impurity=0.1067\\ Samples=1990 \\value=[28,1962]$", 9.5, 9, scale=4))
pgm.add_node(daft.Node("2", r"$\\ \sigma_{cl}<=55.6963}\\ Impurity=0.3323\\ samples=392 \\value=[24,368]$", 5.75, 6.5, scale=4))
pgm.add_node(daft.Node("3", r"$\\ v_{\infty, cl}<=391.5319\\ Impurity=0.0252\\ samples=1598 \\value=[4,1594]$", 13.25, 6.5, scale=4))
pgm.add_node(daft.Node("4", r"$\\ T_{cl}<=35477.9219\\ Impurity=0.133\\ samples=216 \\value=[4,212]$", 3.25, 4.5, scale=4))
pgm.add_node(daft.Node("5", r"$\\ P_{cl}<=0.683\\ Impurity=0.5108\\ samples=176 \\value=[20, 156]$", 8.25, 4.5, scale=4))
pgm.add_node(daft.Node("6", r"$\\ v_{\infty, cl}<=391.2136\\ Impurity=0.0588\\ samples=588 \\value=[4,584]$", 12, 4.5, scale=4))
pgm.add_node(daft.Node("7", r"$\\ Impurity=0.0\\ samples=1010 \\value=[0,1010]$", 14.5, 4.5, scale=4))
pgm.add_node(daft.Node("8", r"$\\ Impurity=0.0472\\ samples=191 \\value=[1,190]$", 2, 2, scale=4))
pgm.add_node(daft.Node("9", r"$\\ Impurity=0.5294\\ samples=25 \\value=[3,22]$", 4.5, 2, scale=4))
pgm.add_node(daft.Node("10", r"$\\ Impurity=0.3228\\ samples=119 \\value=[7,112]$", 7, 2, scale=4))
pgm.add_node(daft.Node("11", r"$\\ Impurity=0.7746\\ samples=57 \\value=[13,44]$", 9.5, 2, scale=4))
pgm.add_node(daft.Node("12", r"$\\ Impurity=0.0463\\ samples=587 \\value=[3,584]$", 12, 2, scale=4))
pgm.add_node(daft.Node("13", r"$\\ Impurity=0.0\\ samples=1 \\value=[1,0]$", 14.5, 2, scale=4))


pgm.add_node(daft.Node("yes", r"$True \; $", 7.48, 7.65, fixed=True))
pgm.add_node(daft.Node("No", r"$\; False$", 11.55, 7.65, fixed=True))

pgm.add_edge("1", "2")
pgm.add_edge("1", "3")

pgm.add_edge("2", "4")
pgm.add_edge("2", "5")

pgm.add_edge("3", "6")
pgm.add_edge("3", "7")


pgm.add_edge("4", "8")
pgm.add_edge("4", "9")

pgm.add_edge("5", "10")
pgm.add_edge("5", "11")

pgm.add_edge("6", "12")
pgm.add_edge("6", "13")

# %%
pgm.render()

# %%
pgm.figure.savefig("clasification_tree.png", dpi=150)
pgm.figure.savefig("clasification_tree.pdf", dpi=150)
